# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set_theme()
import numpy as np

# %%
N = 30
x = np.arange(N)
y = 5 * x - 7 + ( 10 * np.random.randn(N))
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True)
model.fit(x[:, np.newaxis] , y)
yfit = model.predict(x[: , np.newaxis])
plt.scatter(x,y)
plt.plot(x , yfit ,color = 'r')

# %%
from sklearn.datasets._samples_generator import make_blobs
X , Y = make_blobs(n_samples=500 , centers=4 , cluster_std= 1)
plt.scatter(X[:, 0] , X[:, 1] , c=Y , cmap="autumn")

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , Y_train , Y_test = train_test_split(X, Y, test_size= 0.33)

# %%
from sklearn.svm import SVC

# %%
model = SVC(gamma= 'auto')
model.fit(X_train , Y_train)
Y_predict = model.predict(X_test)

# %%
accuracy = 100 * np.sum(Y_predict == Y_test)/Y_test.size
print("Accuracy = " , accuracy , " %")
# Out:
# Accuracy =  100.0  %

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=20)
model.fit(X_train , Y_train)
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
Y_predict = model.predict(X_test)
accuracy = 100 * np.sum(Y_predict == Y_test)/Y_test.size
print("Accuracy = " , accuracy , " %")
# Out:
# Accuracy =  99.39393939393939  %

# %% [markdown]
# ## Ridge Regression Analysis

# %%
from sklearn.linear_model import Ridge
